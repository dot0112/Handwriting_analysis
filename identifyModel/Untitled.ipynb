# %%
# !python valDataGenerator.py
# Out:
# ...
# 폴더 004 처리 중:  65%|██████████████▉        | 195/300 [00:19<00:10, 10.12it/s]
# ...
# ...
# 폴더 148 처리 중:  35%|████████               | 105/300 [00:10<00:18, 10.61it/s]

# %%
# !python main.py train 1000
# Out:
# Usage:
#      python main.py train [<epochs>]
#      python main.py test
#
# 2024-11-26 10:01:19.757176: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-26 10:01:19.813570: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-26 10:01:19.828900: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-26 10:01:19.928575: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...
